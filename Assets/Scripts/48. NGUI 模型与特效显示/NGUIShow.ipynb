# %% [markdown]
# 1. NGUI中显示3D模型的方法
#     - 方法一: 改变NGUI整体层为UI层,改变主摄影机和NGUI摄影机的渲染层级,将想要被UI摄像机渲染的对象设置为UI层,调整模型和UI控件的Z轴距离控制模型显示到UI前/后。主摄像机不要渲染UI层
#     - 方法二: 使用RenderTexture渲染纹理,创建一个专门的摄像机渲染3D模型到RenderTexture上,然后将RenderTexture赋值给UI的RawImage组件显示出来
# 2. NGUI 显示粒子特效
#     - 让Panel和粒子特效处于一个排序层，在粒子特效的Render参数设置自己的层级，大的层级ID会显示到上面
